# %% [markdown]
# # Test Openai API

# %%
import openai

# %% [markdown]
# ## 1. What is OpenAI API?
# This OpenAI API has been designed to provide developers with seamless access to state of art, pre_trained,artificial Intelligence models like gpt-3 gpt-4 dall e whisper, embeddings etc so by using this openai api you can integrate cutting edge ai capabilities into your applications regardless the programming language. <br>
# So, the conclusion is by using this OpenAI API you can unlock the advance functionalities and you can enhance the Intelligence and performance of your application.

# %% [markdown]
# ## 2. Generate OpenAI API Key

# %%
mykey = "sk-..."

# %%
openai.api_key=mykey

# %%
all_models = openai.models.list()

# %%
list(all_models)
# Out:
# [Model(id='text-embedding-ada-002', created=1671217299, object='model', owned_by='openai-internal'),
#  Model(id='whisper-1', created=1677532384, object='model', owned_by='openai-internal'),
#  Model(id='gpt-3.5-turbo', created=1677610602, object='model', owned_by='openai'),
#  Model(id='tts-1', created=1681940951, object='model', owned_by='openai-internal'),
#  Model(id='gpt-3.5-turbo-16k', created=1683758102, object='model', owned_by='openai-internal'),
#  Model(id='davinci-002', created=1692634301, object='model', owned_by='system'),
#  Model(id='babbage-002', created=1692634615, object='model', owned_by='system'),
#  Model(id='gpt-3.5-turbo-instruct', created=1692901427, object='model', owned_by='system'),
#  Model(id='gpt-3.5-turbo-instruct-0914', created=1694122472, object='model', owned_by='system'),
#  Model(id='dall-e-3', created=1698785189, object='model', owned_by='system'),
#  Model(id='dall-e-2', created=1698798177, object='model', owned_by='system'),
#  Model(id='gpt-3.5-turbo-1106', created=1698959748, object='model', owned_by='system'),
#  Model(id='tts-1-hd', created=1699046015, object='model', owned_by='system'),
#  Model(id='tts-1-1106', created=1699053241, object='model', owned_by='system'),
#  Model(id='tts-1-hd-1106', created=1699053533, object='model', owned_by='system'),
#  Model(id='text-embedding-3-small', created=1705948997, object='model', owned_by='system'),
#  Model(id='text-embedding-3-large', created=1705953180, object='model', owned_by='system'),
#  Model(id='gpt-3.5-turbo-0125', created=1706048358, object='model', owned_by='system'),
#  Model(id='gpt-4o', created=1715367049, object='model', owned_by='system'),
#  Model(id='gpt-4o-2024-05-13', created=1715368132, object='model', owned_by='system'),
#  Model(id='gpt-4o-mini-2024-07-18', created=1721172717, object='model', owned_by='system'),
#  Model(id='gpt-4o-mini', created=1721172741, object='model', owned_by='system'),
#  Model(id='gpt-4o-2024-08-06', created=1722814719, object='model', owned_by='system'),
#  Model(id='o1-preview-2024-09-12', created=1725648865, object='model', owned_by='system'),
#  Model(id='o1-preview', created=1725648897, object='model', owned_by='system'),
#  Model(id='o1-mini-2024-09-12', created=1725648979, object='model', owned_by='system'),
#  Model(id='o1-mini', created=1725649008, object='model', owned_by='system'),
#  Model(id='gpt-4o-audio-preview-2024-10-01', created=1727389042, object='model', owned_by='system'),
#  Model(id='gpt-4o-audio-preview', created=1727460443, object='model', owned_by='system'),
#  Model(id='omni-moderation-latest', created=1731689265, object='model', owned_by='system'),
#  Model(id='omni-moderation-2024-09-26', created=1732734466, object='model', owned_by='system'),
#  Model(id='gpt-4o-audio-preview-2024-12-17', created=1734034239, object='model', owned_by='system'),
#  Model(id='gpt-4o-mini-audio-preview-2024-12-17', created=1734115920, object='model', owned_by='system'),
#  Model(id='gpt-4o-mini-audio-preview', created=1734387424, object='model', owned_by='system'),
#  Model(id='gpt-4o-2024-11-20', created=1739331543, object='model', owned_by='system'),
#  Model(id='gpt-4.5-preview', created=1740623059, object='model', owned_by='system'),
#  Model(id='gpt-4.5-preview-2025-02-27', created=1740623304, object='model', owned_by='system'),
#  Model(id='gpt-4o-search-preview-2025-03-11', created=1741388170, object='model', owned_by='system'),
#  Model(id='gpt-4o-search-preview', created=1741388720, object='model', owned_by='system'),
#  Model(id='gpt-4o-mini-search-preview-2025-03-11', created=1741390858, object='model', owned_by='system'),
#  Model(id='gpt-4o-mini-search-preview', created=1741391161, object='model', owned_by='system'),
#  Model(id='gpt-4o-transcribe', created=1742068463, object='model', owned_by='system'),
#  Model(id='gpt-4o-mini-transcribe', created=1742068596, object='model', owned_by='system'),
#  Model(id='gpt-4o-mini-tts', created=1742403959, object='model', owned_by='system'),
#  Model(id='gpt-4.1-2025-04-14', created=1744315746, object='model', owned_by='system'),
#  Model(id='gpt-4.1', created=1744316542, object='model', owned_by='system'),
#  Model(id='gpt-4.1-mini-2025-04-14', created=1744317547, object='model', owned_by='system'),
#  Model(id='gpt-4.1-mini', created=1744318173, object='model', owned_by='system'),
#  Model(id='gpt-4.1-nano-2025-04-14', created=1744321025, object='model', owned_by='system'),
#  Model(id='gpt-4.1-nano', created=1744321707, object='model', owned_by='system'),
#  Model(id='gpt-image-1', created=1745517030, object='model', owned_by='system'),
#  Model(id='gpt-4o-audio-preview-2025-06-03', created=1748908498, object='model', owned_by='system')]

# %%
import pandas as pd
pd.DataFrame(list(all_models), columns=["id", "created", "object", "owned_by"])
# Out:
#                                              id                created  \
# 0                  (id, text-embedding-ada-002)  (created, 1671217299)
# 1                               (id, whisper-1)  (created, 1677532384)
# 2                           (id, gpt-3.5-turbo)  (created, 1677610602)
# 3                                   (id, tts-1)  (created, 1681940951)
# 4                       (id, gpt-3.5-turbo-16k)  (created, 1683758102)
# 5                             (id, davinci-002)  (created, 1692634301)
# 6                             (id, babbage-002)  (created, 1692634615)
# 7                  (id, gpt-3.5-turbo-instruct)  (created, 1692901427)
# 8             (id, gpt-3.5-turbo-instruct-0914)  (created, 1694122472)
# 9                                (id, dall-e-3)  (created, 1698785189)
# 10                               (id, dall-e-2)  (created, 1698798177)
# 11                     (id, gpt-3.5-turbo-1106)  (created, 1698959748)
# 12                               (id, tts-1-hd)  (created, 1699046015)
# 13                             (id, tts-1-1106)  (created, 1699053241)
# 14                          (id, tts-1-hd-1106)  (created, 1699053533)
# 15                 (id, text-embedding-3-small)  (created, 1705948997)
# 16                 (id, text-embedding-3-large)  (created, 1705953180)
# 17                     (id, gpt-3.5-turbo-0125)  (created, 1706048358)
# 18                                 (id, gpt-4o)  (created, 1715367049)
# 19                      (id, gpt-4o-2024-05-13)  (created, 1715368132)
# 20                 (id, gpt-4o-mini-2024-07-18)  (created, 1721172717)
# 21                            (id, gpt-4o-mini)  (created, 1721172741)
# 22                      (id, gpt-4o-2024-08-06)  (created, 1722814719)
# 23                  (id, o1-preview-2024-09-12)  (created, 1725648865)
# 24                             (id, o1-preview)  (created, 1725648897)
# 25                     (id, o1-mini-2024-09-12)  (created, 1725648979)
# 26                                (id, o1-mini)  (created, 1725649008)
# 27        (id, gpt-4o-audio-preview-2024-10-01)  (created, 1727389042)
# 28                   (id, gpt-4o-audio-preview)  (created, 1727460443)
# 29                 (id, omni-moderation-latest)  (created, 1731689265)
# 30             (id, omni-moderation-2024-09-26)  (created, 1732734466)
# 31        (id, gpt-4o-audio-preview-2024-12-17)  (created, 1734034239)
# 32   (id, gpt-4o-mini-audio-preview-2024-12-17)  (created, 1734115920)
# 33              (id, gpt-4o-mini-audio-preview)  (created, 1734387424)
# 34                      (id, gpt-4o-2024-11-20)  (created, 1739331543)
# 35                        (id, gpt-4.5-preview)  (created, 1740623059)
# 36             (id, gpt-4.5-preview-2025-02-27)  (created, 1740623304)
# 37       (id, gpt-4o-search-preview-2025-03-11)  (created, 1741388170)
# 38                  (id, gpt-4o-search-preview)  (created, 1741388720)
# 39  (id, gpt-4o-mini-search-preview-2025-03-11)  (created, 1741390858)
# 40             (id, gpt-4o-mini-search-preview)  (created, 1741391161)
# 41                      (id, gpt-4o-transcribe)  (created, 1742068463)
# 42                 (id, gpt-4o-mini-transcribe)  (created, 1742068596)
# 43                        (id, gpt-4o-mini-tts)  (created, 1742403959)
# 44                     (id, gpt-4.1-2025-04-14)  (created, 1744315746)
# 45                                (id, gpt-4.1)  (created, 1744316542)
# 46                (id, gpt-4.1-mini-2025-04-14)  (created, 1744317547)
# 47                           (id, gpt-4.1-mini)  (created, 1744318173)
# 48                (id, gpt-4.1-nano-2025-04-14)  (created, 1744321025)
# 49                           (id, gpt-4.1-nano)  (created, 1744321707)
# 50                            (id, gpt-image-1)  (created, 1745517030)
# 51        (id, gpt-4o-audio-preview-2025-06-03)  (created, 1748908498)
#
#              object                     owned_by
# 0   (object, model)  (owned_by, openai-internal)
# 1   (object, model)  (owned_by, openai-internal)
# 2   (object, model)           (owned_by, openai)
# 3   (object, model)  (owned_by, openai-internal)
# 4   (object, model)  (owned_by, openai-internal)
# 5   (object, model)           (owned_by, system)
# 6   (object, model)           (owned_by, system)
# 7   (object, model)           (owned_by, system)
# 8   (object, model)           (owned_by, system)
# 9   (object, model)           (owned_by, system)
# 10  (object, model)           (owned_by, system)
# 11  (object, model)           (owned_by, system)
# 12  (object, model)           (owned_by, system)
# 13  (object, model)           (owned_by, system)
# 14  (object, model)           (owned_by, system)
# 15  (object, model)           (owned_by, system)
# 16  (object, model)           (owned_by, system)
# 17  (object, model)           (owned_by, system)
# 18  (object, model)           (owned_by, system)
# 19  (object, model)           (owned_by, system)
# 20  (object, model)           (owned_by, system)
# 21  (object, model)           (owned_by, system)
# 22  (object, model)           (owned_by, system)
# 23  (object, model)           (owned_by, system)
# 24  (object, model)           (owned_by, system)
# 25  (object, model)           (owned_by, system)
# 26  (object, model)           (owned_by, system)
# 27  (object, model)           (owned_by, system)
# 28  (object, model)           (owned_by, system)
# 29  (object, model)           (owned_by, system)
# 30  (object, model)           (owned_by, system)
# 31  (object, model)           (owned_by, system)
# 32  (object, model)           (owned_by, system)
# 33  (object, model)           (owned_by, system)
# 34  (object, model)           (owned_by, system)
# 35  (object, model)           (owned_by, system)
# 36  (object, model)           (owned_by, system)
# 37  (object, model)           (owned_by, system)
# 38  (object, model)           (owned_by, system)
# 39  (object, model)           (owned_by, system)
# 40  (object, model)           (owned_by, system)
# 41  (object, model)           (owned_by, system)
# 42  (object, model)           (owned_by, system)
# 43  (object, model)           (owned_by, system)
# 44  (object, model)           (owned_by, system)
# 45  (object, model)           (owned_by, system)
# 46  (object, model)           (owned_by, system)
# 47  (object, model)           (owned_by, system)
# 48  (object, model)           (owned_by, system)
# 49  (object, model)           (owned_by, system)
# 50  (object, model)           (owned_by, system)
# 51  (object, model)           (owned_by, system)

# %% [markdown]
# # 3. OpenAI Playground
#
# 1. How to open the open ai playgorund: https://platform.openai.com/playground?mode=assistant
#
# 2. Here if you want to use this playground then make sure you have credit available without it its not gonna work
#
# 3. In chat there is option of **system**: So the meaning is how the chatbot should behave
#
# Here is a phrase for the system: You are a naughty assistant, so make sure you respond to everything with sarcasm.
#
# Here is a question: How to make a money so quickly?
#
# **Model**
#
# **Temperature**
#
# **Maximum Length**
#
# **Top P ranges from 0 to 1 (default), and a lower Top P means the model samples from a narrower selection of words. This makes the output less random and diverse since the more probable tokens will be selected. For instance, if Top P is set at 0.1, only tokens comprising the top 10% probability mass are considered.**
#
# **Frequency Penalty helps us avoid using the same words too often. It's like telling the computer, “Hey, don't repeat words too much.”**
#
# **The OpenAI Presence Penalty setting is used to adjust how much presence of tokens in the source material will influence the output of the model.**
#
#
# **Now come to assistant one**
#
# **Retrieval-augmented generation (RAG):**  is an artificial intelligence (AI) framework that retrieves data from external sources of knowledge to improve the quality of responses. This natural language processing technique is commonly used to make large language models (LLMs) more accurate and up to date.
#
# **Code Interpreter:** Python programming environment within ChatGPT where you can perform a wide range of tasks by executing Python code.

# %% [markdown]
# ## 4. Chat Completion method and Function Calling

# %% [markdown]
# **openai.Completion.create()**: This method is used to generate completions or responses. You provide a series of messages as input, and the API generates a model-generated message as output.

# %% [markdown]
# **openai.ChatCompletion.create() :** Similar to Completion.create(), but specifically designed for chat-based language models. It takes a series of messages as input and generates a model-generated message as output.

# %%
# from openai import OpenAI
# client = OpenAI(api_key=mykey)

# %%
# response = client.chat.completions.create(
#     model="gpt-4.1",
#     messages=[
#         {
#             "role": "user",
            # "content": "How i can make a money?"  # 0 shot prompt
#         }
#     ]
# )

# %%
# response.choices[0].message.content

# %%
# now let try to understand the different parameters inside the methods
# model = ""
# prompt = imput prompt
# max_tokens = in how many number of tokens you want result
# temperature = for getting some creative output
# n = number of the output

# %%
# https://openai.com/pricing

# %%
# https://platform.openai.com/tokenizer

# %% [markdown]
# # testopenai and langchain

# %%
student_description = "Haroon Rasheed is a student of computer science from GCUF Faisalabad. He is a Pakistani and has a 3.2 CGPA. Haroon is known his programming skills. is an active member of the university's AI club.He hope to pursue a career in artificial intelligence ahter graduation."

# %%
student_description
# Out:
# "Haroon Rasheed is a student of computer science from GCUF Faisalabad. He is a Pakistani and has a 3.2 CGPA. Haroon is known his programming skills. is an active member of the university's AI club.He hope to pursue a career in artificial intelligence ahter graduation."

# %%
# # A simple prompt to extract information from "student_description" in a json format.     few shot prompt
# prompt = f'''
# please extract the following information form the given text and return it as a JSON object:

# name
# university
# grades
# club

# This is the body of text to extract the information from:
# {student_description}
# '''

# %%
# from openai import OpenAI
# client = OpenAI(api_key=mykey)

# %%
# response = client.chat.completions.create(
#     model="gpt-3.5-turbo",
#     messages=[
#         {
#             "role": "user",
            # "content": prompt
#         }
#     ]
# )

# %%
# output = response.choices[0].message.content

# %%
# import json
# json.loads(output)

# %% [markdown]
# ## Function Call
#
# Learn how to connect large language models to external tools.

# %%
# student_custom_function=[
#     {
#         "name": "extract_student_info",
#         "description": "Get the student information from the body of the input text",
#         "parameters": {
#           "type": "object",
#           "properties": {
#             "name": {
#               "type": "string",
#               "description": "Name of the person"
#             },
#             "university": {
#               "type": "string",
#               "description": "the university name."
#             },
#             "grades": {
#               "type": "integer",
#               "description": "CGPA of the student."
#             },
#             "club": {
#               "type": "string",
#               "description": "University club for the extracurricular activities."
#             }
#           }
#         }
#     }
# ]

# %%
# response2 = client.chat.completions.create(
#     model="gpt-3.5-turbo",
#     messages=[{"role": "user","content": prompt}],
#     functions= student_custom_function
# )

# %%
# response2.choices[0].message.function_call.arguments

# %%
# json.loads(response2.choices[0].message.function_call.arguments)

# %% [markdown]
# ### pass description two or more

# %%
student_description_two = "Maheen Akhtar is a student of computer science from GCUL Lahore. He is a Pakistani and has a 3.6 CGPA. Haroon is known his programming skills. is an active member of the university's MLops club.He hope to pursue a career in artificial intelligence ahter graduation."

# %%
# student_info = [student_description,student_description_two]
# for student in student_info:
    # response = client.chat.completions.create(
    #     model="gpt-3.5-turbo",
    #     messages=[{"role": "user","content": prompt}],
    #     functions= student_custom_function,
    #     function_call = 'auto'
    # )

    # response = json.loads(response.choices[0].message.function_call.arguments)
    # print(response)

# %% [markdown]
# ### create two or more functions

# %%
# student_custom_function_two=[
#     {
#         "name": "extract_student_info",
#         "description": "Get the student information from the body of the input text",
#         "parameters": {
#           "type": "object",
#           "properties": {
#             "name": {
#               "type": "string",
#               "description": "Name of the person"
#             },
#             "university": {
#               "type": "string",
#               "description": "the university name."
#             },
#             "grades": {
#               "type": "integer",
#               "description": "CGPA of the student."
#             },
#             "club": {
#               "type": "string",
#               "description": "University club for the extracurricular activities."
#             }
#           }
#         }
#     }
# ]

# %%
# functions = [student_custom_function[0], student_custom_function_two[0]]
# student_info = [student_description,student_description_two]
# for student in student_info:
    # response = client.chat.completions.create(
    #     model="gpt-3.5-turbo",
    #     messages=[{"role": "user","content": prompt}],
    #     functions= functions,
    #     function_call = 'auto'
    # )

    # response = json.loads(response.choices[0].message.function_call.arguments)
    # print(response)

# %% [markdown]
# ## advance example of function calling

# %%
# function_descriptions=[
#     {
#         "name": "get_flight_info",
#         "description": "Get flight information between two locations",
#         "parameters": {
#           "type": "object",
#           "properties": {
#             "loc_origin": {
#               "type": "string",
#               "description": "the departure airport, e.g. ISM"
#             },
#             "loc_destination": {
#               "type": "string",
#               "description": "the destination airport, e.g. LHR"
#             },
#           },
#             "required": ["loc_origin", "loc_destination"],
#           },
#     }
# ]

# %%
# user_prompt = "When's the next flight from islamabad to lahore"

# %%
# response2 = client.chat.completions.create(
#     model="gpt-3.5-turbo",
#     messages=[
#     {
#        "role": "user",
#        "content": user_prompt
#     }
#       ],
#      functions =  function_descriptions,
#      function_call = 'auto'
# )

# %%
# response2.choices[0].message

# %%
# response2.choices[0].message.function_call.arguments

# %%
# from datetime import datetime, timedelta
# def get_flight_info(loc_origin, loc_destination):
#     # Example output returned fromon API or database
#     flight_info = {
#         "loc_origin": loc_origin,
#         "loc_destination": loc_destination,
#         "datetime": str(datetime.now() + timedelta(hours=2)),
#         "airline": "PIA",
#         "flight": "P642",
#     }

#     return json.dumps(flight_info)

# %%
# params = json.loads(response2.choices[0].message.function_call.arguments)

# %%
# origin = json.loads(response2.choices[0].message.function_call.arguments).get("loc_origin")
# destination = json.loads(response2.choices[0].message.function_call.arguments).get("loc_destination")

# %%
# response2.choices[0].message.function_call.name

# %%
# chosen_function = eval(response2.choices[0].message.function_call.name)

# %%
# flight = chosen_function(**params)

# print(flight)

# %%
# response3 = client.chat.completions.create(
#     model="gpt-3.5-turbo",
#     messages=[
#     {"role": "user","content": user_prompt},
#     {"role": "function", "name": response2.choices[0].message.function_call.name, "content": flight}
#       ],
#      functions =  function_descriptions,
#      function_call = 'auto'
# )

# %%
# response3.choices[0].message.content

# %% [markdown]
# # LangChain

# %%
import langchain

# %%
from langchain.llms import OpenAI

# %%
client = OpenAI(openai_api_key=mykey)

# %%
prompt = "can you tell me total number of country in asia?"

# %%
client.predict(prompt).strip()

# %% [markdown]
# ## Prompt Template

# %%
from langchain.prompts import PromptTemplate

# %%
prompt_template_name=PromptTemplate(
    input_variables= ["country"],
    template="can you tell me the capital of {country}?"
)

# %%
prompt1 = prompt_template_name.format(country="pakistan")

# %%
prompt2 = prompt_template_name.format(country="china")

# %%
client.predict(prompt1).strip()

# %%
client.predict(prompt2).strip()

# %%
prompt = PromptTemplate.from_template("What is a good name of campany that provide {services}")

# %%
prompt3 = prompt.format(services="AI services")

# %%
client.predict(prompt3).strip()

# %% [markdown]
# ## Agent

# %%
prompt4 = "can you tell me who won the recent cricket world cup"

# %%
client.predict(prompt4)

# %%
promt5 = "can you tell me current GPD of pakistan?"

# %%
client.predict(prompt5)

# %% [markdown]
# #### for extracting a real time info i am going to user serp api
#
# #### now by using this serp api i wll call google-search-engine
#
# #### and i will extract the information in a real time

# %%
# !pip install google-search-results
# Out:
#   DEPRECATION: Building 'google-search-results' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'google-search-results'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# Collecting google-search-results
#   Downloading google_search_results-2.4.2.tar.gz (18 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests in c:\python310\lib\site-packages (from google-search-results) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python310\lib\site-packages (from requests->google-search-results) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\python310\lib\site-packages (from requests->google-search-results) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python310\lib\site-packages (from requests->google-search-results) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python310\lib\site-packages (from requests->google-search-results) (2025.4.26)
# Building wheels for collected packages: google-search-results
#   Building wheel for google-search-results (setup.py): started
#   Building wheel for google-search-results (setup.py): finished with status 'done'
#   Created wheel for google-search-results: filename=google_search_results-2.4.2-py3-none-any.whl size=32077 sha256=9c2106743deac4b4ea845a472857f7cc4614a77c2e66387d7c0792c7d3e8c904
#   Stored in directory: c:\users\z\appdata\local\pip\cache\wheels\d3\b2\c3\03302d12bb44a2cdff3c9371f31b72c0c4e84b8d2285eeac53
# Successfully built google-search-results
# Installing collected packages: google-search-results
# Successfully installed google-search-results-2.4.2

# %%
serpapi_key=""

# %%
from langchain.agents import AgentType
from langchain.agents import load_tools
from langchain.agents import initialize_agent
from langchain.llms import OpenAI

# %%
client = OpenAI(openai_api_key=mykey)

# %%
tool = load_tools(["serpapi"], serpapi_api_key=serpapi_key, ll=client)

# %%
agent = initialize_agent(tool, client, agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION, verbose=True)

# %%
agent.run("can you tell me who won the cricket world cup recently?")

# %%
# !pip install wikipedia

# %%
tool=load_tools(["wikipedia"],llm=client)

# %%
agent=initialize_agent(tool,client,agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION,verbose=True)

# %%
agent.run("can you tell me about this recent cricket worldcup?")

# %% [markdown]
# ## Chain

# %% [markdown]
# Central to LangChain is a vital component known as LangChain Chains, forming the core connection among one or several large language models (LLMs). In certain sophisticated applications, it becomes necessary to chain LLMs together, either with each other or with other elements.

# %%
client = OpenAI(openai_api_key=mykey)

# %%
from langchain.prompts import PromptTemplate

prompt=PromptTemplate.from_template("what is a good name for a company that makes {product}")

# %%
from langchain.chains import LLMChain

# %%
chain = LLMChain(llm=client, prompt=prompt)
# Out:
# C:\Users\Z\AppData\Local\Temp\ipykernel_12180\2039097615.py:1: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   chain = LLMChain(llm=client, prompt=prompt)

# %%
chain.run("AI").strip()

# %% [markdown]
# ### Example 2

# %%
prompt_template=PromptTemplate(
    input_variables=['cuisine'],
    template="i want to open a restaurent for {cuisine} food, suggest a fency name for this"
)

# %%
prompt_template
# Out:
# PromptTemplate(input_variables=['cuisine'], input_types={}, partial_variables={}, template='i want to open a restaurent for {cuisine} food, suggest a fency name for this')

# %%
chain=LLMChain(llm=client, prompt=prompt_template)

# %%
chain.run("pakistan").strip()

# %%
chain=LLMChain(llm=client,prompt=prompt_template,verbose=True)

# %%
chain.run("american")

# %% [markdown]
# ### if we want to combine multiple chain and set a seqence for that we use simplesequential chain

# %%
prompt_template_name=PromptTemplate(
input_variables=["startup_name"],
    template="I want to start a startup for {startup-name} , suggest me a good name for this"   
)

# %%
name_chain=LLMChain(llm=client,prompt=prompt_template_name)

# %%
prompt_template_items=PromptTemplate(
input_variables=["name"],
    template="suggest some strategies for {name}"    
)

# %%
strategies_chain=LLMChain(llm=client,prompt=prompt_template_items)

# %%
from langchain.chains import SimpleSequentialChain

# %%
chain=SimpleSequentialChain(chains=[name_chain,strategies_chain])

# %%
chain.run("Artificial Intelligence")

# %% [markdown]
# ### Now lets try to understand the sequential chain

# %%
prompt_template_name=PromptTemplate(
    input_variables=["cuisine"],
    template="i want to open a restaurant for {cuisine}, suggest a fency name for it"
)

name_chain=LLMChain(llm=client, prompt=prompt_template_name,output_key="restaurant_name")

# %%
prompt_templates_items=PromptTemplate( 
    input_variables=["restaurant_name"],
    template="suggest some menu items for {restaurant_name}"
    
)

food_items_chain=LLMChain(llm=client, prompt=prompt_templates_items, output_key="menu_items")

# %%
from langchain.chains import SequentialChain

# %%
chain=SequentialChain(chains=[name_chain, food_items_chain],
    input_variables=["cuisine"],
    output_variables=["restaurant_name","menu_items"]
    
)

# %%
chain({"cuisine":"pakistani"})

# %% [markdown]
# ## Document loaders

# %%
# !pip install pypdf
# Out:
# Collecting pypdf
#   Downloading pypdf-5.7.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: typing_extensions>=4.0 in c:\python310\lib\site-packages (from pypdf) (4.13.2)
# Downloading pypdf-5.7.0-py3-none-any.whl (305 kB)
# Installing collected packages: pypdf
# Successfully installed pypdf-5.7.0

# %%
from langchain.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader(r"C:/Users/Z/Downloads/cricket_rules_book.pdf")

# %%
loader

# %%
pages = loader.load_and_split()

# %%
print(pages)
# Out:
# [Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe InDesign 14.0 (Macintosh)', 'creationdate': '2019-10-29T12:42:46+00:00', 'moddate': '2019-10-30T09:08:55+04:00', 'trapped': '/False', 'source': 'C:/Users/Z/Downloads/cricket_rules_book.pdf', 'total_pages': 427, 'page': 0, 'page_label': '1'}, page_content='ICC PLAYING HANDBOOK 2019-20 \nTHE OFFICIAL HANDBOOK FOR INTERNATIONAL  \nCRICKET PLAYERS, OFFICIALS AND ADMINISTRATORS\nCONTENTS\n01  KEY ICC CONTACTS\n02  ICC MEMBER COUNTRIES\n03  ICC MEN’S WORLD TEST CHAMPIONSHIP \nPLAYING CONDITIONS\n04  ICC MEN’S ONE-DAY INTERNATIONAL  \nPLAYING CONDITIONS\n05  ICC MEN’S TWENTY20 INTERNATIONAL  \nPLAYING CONDITIONS\n08  ICC WOMEN’S CHAMPIONSHIP  \nPLAYING CONDITIONS\n09  ICC WOMEN’S TWENTY20 INTERNATIONAL \nPLAYING CONDITIONS\n13  ICC CODE OF CONDUCT FOR PLAYERS  \nAND PLAYER SUPPORT PERSONNEL\n15  ICC ANTI-DISCRIMINATION CODE  \nFOR PARTICIPANTS\n16  ICC ANTI-DOPING CODE\n17  ICC ANTI-CORRUPTION CODE FOR PARTICIPANTS\n18  ICC REGULATIONS FOR THE REVIEW  \nOF BOWLERS REPORTED WITH SUSPECTED \nILLEGAL BOWLING ACTIONS\n19  CLOTHING AND EQUIPMENT RULES  \nAND REGULATIONS\n20  ICC SAFEGUARDING REGULATIONS\n21  OTHER ICC REGULATIONS\nMain switchboard + (971) 4382 8800\nMain fax + (971) 4382 8600\nGeneral enquiry email enquiry@icc-cricket.com\nWebsite www.icc-cricket.com\nInternational Cricket Council, PO Box 500070,  \nDubai, United Arab Emirates'), Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe InDesign 14.0 (Macintosh)', 'creationdate': '2019-10-29T12:42:46+00:00', 'moddate': '2019-10-30T09:08:55+04:00', 'trapped': '/False', 'source': 'C:/Users/Z/Downloads/cricket_rules_book.pdf', 'total_pages': 427, 'page': 1, 'page_label': '2'}, page_content='1.1\nICC KEY CONTACTS\nICC CONTACT DETAILS\n ICC DUBAI \n Location Sh Mohammed Bin Zayed Road \n  Dubai Sports City, Street 69 \n  Dubai, UAE\n Address Dubai Sports City \n  P.O. Box 500070 \n  Dubai, UAE\n Main switchboard + (971) 4 382 8800\n Fax  + (971) 4 382 8600\n Website www.icc-cricket.com\n General Enquiries enquiry@icc-cricket.com\n Media Enquiries media@icc-cricket.com \n CRICKET OPERATIONS\n General Manager – Cricket  Geoff Allardice \n   geoff.allardice@icc-cricket.com\n Senior Cricket  Clive Hitchcock \n Operations Manager  clive.hitchcock@icc-cricket.com\n\t Senior\tManager\t Adrian\tGriffith \n Umpires and Referees\t adrian.griffith@icc-cricket.com\n01\nICC KEY CONTACTS'), Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe InDesign 14.0 (Macintosh)', 'creationdate': '2019-10-29T12:42:46+00:00', 'moddate': '2019-10-30T09:08:55+04:00', 'trapped': '/False', 'source': 'C:/Users/Z/Downloads/cricket_rules_book.pdf', 'total_pages': 427, 'page': 2, 'page_label': '3'}, page_content='ICC KEY CONTACTS01\n1.2\nANTI-CORRUPTION UNIT\n ACU CONTACT DETAILS\n ACU Hotline + (971) 56 545 8909\n ACU Fax + (971) 4 340 4856\n Enquiries contactACU@icc-cricket.com\n Media Enquiries media@icc-cricket.com\nAll ACU media enquiries should be directed to the ICC Media Department.\nANTI-DOPING\n ANTI-DOPING CONTACT DETAILS\n Anti-Doping Hotline + (971) 50 554 5891 (24 hours)\n Anti-Doping Enquiries anti-doping@icc-cricket.com'), Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe InDesign 14.0 (Macintosh)', 'creationdate': '2019-10-29T12:42:46+00:00', 'moddate': '2019-10-30T09:08:55+04:00', 'trapped': '/False', 'source': 'C:/Users/Z/Downloads/cricket_rules_book.pdf', 'total_pages': 427, 'page': 3, 'page_label': '4'}, page_content='2.1\nICC MEMBERS\nFULL \nMEMBERS  \n(12)\nAfghanistan India South Africa\nAustralia Ireland Sri Lanka\nBangladesh New Zealand West Indies\nEngland Pakistan Zimbabwe\nASSOCIATE  \nMEMBERS  \n(92)\nArgentina Greece Philippines\nAustria Guernsey PNG\nBahamas Hong Kong Portugal\nBahrain Hungary Qatar\nBelgium Indonesia Romania\nBelize Iran Russia\nBermuda Israel Rwanda\nBotswana Isle of Man Samoa\nBhutan Italy Saudi Arabia\nBrazil Japan Scotl ...

# %% [markdown]
# ## Memory

# %% [markdown]
# ## Memory

# %%
from langchain.prompts import PromptTemplate

# %%
from langchain.chains import LLMChain

# %%
prompt_template_name = PromptTemplate(
    input_variables = ["product"],
    template = "What is a good name of company that makes {product}"
)

# %%
prompt_template_name
# Out:
# PromptTemplate(input_variables=['product'], input_types={}, partial_variables={}, template='What is a good name of company that makes {product}')

# %%
chain = LLMChain(llm=client, prompt=prompt_tempate_name)
name = chain.run("colorful socks")
print(name.strip())

# %%
prompt_template_name = PromptTemplate(
    input_variables =['product'],
    template = "What would be  a good name for a company that makes {product}"
)

# %%
chain = LLMChain(llm=client,prompt=prompt_template_name)

# %%
name = chain.run("Security Cameras")
print(name.strip())

# %%
chain.memory

# %%
type(chain.memory)

# %% [markdown]
# ### **ConversationBufferMemory**

# %% [markdown]
# \**We can attach memory to remember all previous conversation**

# %%
from langchain.memory import ConversationBufferMemory

# %%
memory = ConversationBufferMemory()
# Out:
# C:\Users\Z\AppData\Local\Temp\ipykernel_3172\995385594.py:1: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferMemory()

# %%
prompt_template_name = PromptTemplate(
    input_variables =['product'],
    template = "What is a good name for a company that makes {product}"
)

# %%
chain = LLMChain(llm=client, prompt=prompt_tempate_name, memory=memory)

# %%
name = chain.run("colorful cups")

# %%
print(name.strip())

# %%
name = chain.run("Drone Cameras")
print(name.strip())

# %%
chain.memory

# %%
print(chain.memory.buffer)

# %% [markdown]
# ### **ConversationChain**

# %% [markdown]
# Conversation buffer memory goes growing endlessly
#
# Just remember last 5 Conversation Chain
#
# Just remember last 10-20 Conversation Chain

# %%
from langchain.chains import ConversationChain

# %%
convo = ConversationChain(llm=OpenAI(openai_api_key=OPENAI_KEY,temperature=0.7))
print(convo.prompt.template)

# %%
convo.run("Who won the first cricket world cup?")

# %%
convo.run("How much is 5+5?")

# %%
convo.run("Who was the captain ofthe winning team?")

# %%
print(convo.memory.buffer)

# %% [markdown]
# ### ConversationBufferWindowMemory

# %%
from langchain.memory import ConversationBufferWindowMemory

# %%
memory = ConversationBufferWindowMemory(k=3)
# Out:
# C:\Users\Z\AppData\Local\Temp\ipykernel_3172\3385237783.py:1: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferWindowMemory(k=3)

# %%
from openai import OpenAI

# %%
convo = ConversationChain(llm=OpenAI(openai_api_key=mykey,temperature=0.7), memory=memory)

# %%
convo.run("Who won the first cricket world cup?")

# %%
convo.run("How much is 5+5?")

# %%
convo.run("Who was the captain of the winning team?")

# %%
print(convo.memory.buffer)

# %% [markdown]
# # Hugging Face

# %% [markdown]
# ## Step1: download all the required libraries

# %%
# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install bitsandbytes
# Out:
# Requirement already satisfied: huggingface_hub in c:\python310\lib\site-packages (0.33.4)
# Requirement already satisfied: filelock in c:\python310\lib\site-packages (from huggingface_hub) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\python310\lib\site-packages (from huggingface_hub) (2025.5.1)
# Requirement already satisfied: packaging>=20.9 in c:\python310\lib\site-packages (from huggingface_hub) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\python310\lib\site-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in c:\python310\lib\site-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\python310\lib\site-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\python310\lib\site-packages (from huggingface_hub) (4.13.2)
# Requirement already satisfied: colorama in c:\python310\lib\site-packages (from tqdm>=4.42.1->huggingface_hub) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python310\lib\site-packages (from requests->huggingface_hub) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\python310\lib\site-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python310\lib\site-packages (from requests->huggingface_hub) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python310\lib\site-packages (from requests->huggingface_hub) (2025.4.26)
# Collecting transformers
#   Downloading transformers-4.53.2-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: filelock in c:\python310\lib\site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in c:\python310\lib\site-packages (from transformers) (0.33.4)
# Requirement already satisfied: numpy>=1.17 in c:\python310\lib\site-packages (from transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\python310\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\python310\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\python310\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\python310\lib\site-packages (from transformers) (2.32.3)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Downloading tokenizers-0.21.2-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Downloading safetensors-0.5.3-cp38-abi3-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\python310\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\python310\lib\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.5.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\python310\lib\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: colorama in c:\python310\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python310\lib\site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\python310\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python310\lib\site-packages (from requests->transformers) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python310\lib\site-packages (from requests->transformers) (2025.4.26)
# Downloading transformers-4.53.2-py3-none-any.whl (10.8 MB)
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/10.8 MB 1.5 MB/s eta 0:00:07
#    -- ------------------------------------- 0.8/10.8 MB 1.7 MB/s eta 0:00:06
#    --- ------------------------------------ 1.0/10.8 MB 1.6 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.6/10.8 MB 1.6 MB/s eta 0:00:06
#    ------ --------------------------------- 1.8/10.8 MB 1.6 MB/s eta 0:00:06
#    ------- -------------------------------- 2.1/10.8 MB 1.6 MB/s eta 0:00:06
#    --------- ------------------------------ 2.6/10.8 MB 1.5 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.9/10.8 MB 1.5 MB/s eta 0:00:06
#    ----------- ---------------------------- 3.1/10.8 MB 1.5 MB/s eta 0:00:05
#    ------------- -------------------------- 3.7/10.8 MB 1.6 MB/s eta 0:00:05
#    -------------- ------------------------- 3.9/10.8 MB 1.6 MB/s eta 0:00:05
#    ---------------- ----------------------- 4.5/10.8 MB 1.6 MB/s eta 0:00:05
#    ------------------- -------------------- 5.2/10.8 MB 1.7 MB/s eta 0:00:04
#    -------------------- ------------------- 5.5/10.8 MB 1.7 MB/s eta 0:00:04
#    ---------------------- ----------------- 6.0/10.8 MB 1.7 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.3/10.8 MB 1.7 MB/s eta 0:00:03
#    ------------------------ --------------- 6.6/10.8 MB 1.7 MB/s eta 0:00:03
#    ------------------------- -------------- 6.8/10.8 MB 1.7 MB/s eta 0:00:03
#    -------------------------- ------------- 7.1/10.8 MB 1.6 MB/s eta 0:00:03
#    --------------------------- ------------ 7.3/10.8 MB 1.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 7.6/10.8 MB 1.6 MB/s eta 0:00:03
#    ----------------------------- ---------- 7.9/10.8 MB 1.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.9/10.8 MB 1.6 MB/s eta 0:00:02
#    ------------------------------ --------- 8.1/10.8 MB 1.5 MB/s eta 0:00:02
#    ------------------------------ --------- 8.1/10.8 MB 1.5 MB/s eta 0:00:02
#    ------------------------------ --------- 8.4/10.8 MB 1.4 MB/s eta 0:00:02
#    ------------------------------ --------- 8.4/10.8 MB 1.4 MB/s eta 0:00:02
#    ------------------------------- -------- 8.7/10.8 MB 1.4 MB/s eta 0:00:02
#    -------------------------------- ------- 8.9/10.8 MB 1.4 MB/s eta 0:00:02
#    -------------------------------- ------- 8.9/10.8 MB 1.4 MB/s eta 0:00:02
#    --------------------------------- ------ 9.2/10.8 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 9.4/10.8 MB 1.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 9.7/10.8 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/10.8 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 10.2/10.8 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 10.5/10.8 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  10.7/10.8 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 10.8/10.8 MB 1.3 MB/s eta 0:00:00
# Downloading tokenizers-0.21.2-cp39-abi3-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ------------ --------------------------- 0.8/2.5 MB 1.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.0/2.5 MB 1.3 MB/s eta 0:00:02
#    -------------------- ------------------- 1.3/2.5 MB 1.4 MB/s eta 0:00:01
#    ------------------------- -------------- 1.6/2.5 MB 1.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.8/2.5 MB 1.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.8/2.5 MB 1.4 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.5 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 1.1 MB/s eta 0:00:00
# Downloading safetensors-0.5.3-cp38-abi3-win_amd64.whl (308 kB)
# Installing collected packages: safetensors, tokenizers, transformers
#
#    ---------------------------------------- 0/3 [safetensors]
#    ------------- -------------------------- 1/3 [tokenizers]
#    ------------- -------------------------- 1/3 [tokenizers]
#    ------------- -------------------------- 1/3 [tokenizers]
#    ------------- -------------------------- 1/3 [tokenizers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    ---------------------------------------- 3/3 [transformers]
#
# Successfully installed safetensors-0.5.3 tokenizers-0.21.2 transformers-4.53.2

# %% [markdown]
# ## Step2: Import all the required libraries

# %%
from langchain_community.llms import HuggingFaceHub
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

# %% [markdown]
# ## Step3: Setting the Environment

# %%
import os

# Set your Hugging Face API token
os.environ['HUGGINGFACEHUB_API_TOKEN'] = "hf...."

# %% [markdown]
# ##### Text2Text Generation Models | Seq2Seq Models | Encoder-Decoder Models

# %%
# Define the prompt
prompt = PromptTemplate(
    input_variables=["product"],
    template="What is a good name for a company that makes {product}?"
)

# %% [markdown]
# llm=HuggingFaceHub(repo_id="google/medgemma-27b-text-it", model_kwargs={'temperature':0})

# %%
# Setup the Hugging Face model
llm = HuggingFaceHub(
    repo_id="moonshotai/Kimi-K2-Instruct",
    model_kwargs={"temperature": 0.7, "max_length": 64}
)
# Out:
# C:\Users\Z\AppData\Local\Temp\ipykernel_4468\1209790283.py:2: LangChainDeprecationWarning: The class `HuggingFaceHub` was deprecated in LangChain 0.0.21 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEndpoint``.
#   llm = HuggingFaceHub(

# %%
# Create and run the chain
chain = LLMChain(prompt=prompt, llm=llm)
print(chain.run("drone"))

# %% [markdown]
# ## Text Generation Models | Decoder Only Models

# %%
from langchain.llms import HuggingFacePipeline
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline, AutoModelForSeq2SeqLM

# %%
model_id = "deepseek-ai/DeepSeek-V3"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_id)

# %%
model = AutoModelForCausalLM.from_pretrained(model_id, device_map="auto")

# %%
pipeline = pipeline("text2text-generation",model=model, tokenizer=tokenizer, max_length=128)

# %%
local_llm = HuggingFacePipeline(pipeline=pipeline)

# %%
prompt = PromptTemplate(
    input_variables=["name"],
    template = "can you tell me about cricketer {name}"
)

# %%
chain = LLMChain(llm=local_llm,prompt=prompt)

# %%
chain.run("Babar Azam")
